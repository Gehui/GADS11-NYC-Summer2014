# %% [markdown]
# #Agenda
#
# - Define the problem and the approach
# - Data basics: loading data, looking at your data, basic commands
# - <p style="color: red">Handling missing values</p>
# - Intro to scikit-learn
# - Grouping and aggregating data
# - Feature selection
# - Fitting and evaluating a model
# - Deploying your work

# %% [markdown]
# #In this workbook you will
# - Learn about imputation and what it's used for
# - Use the KNearestNeighbors algorithm to impute data
# - Come up with your own imputation strategy

# %% [markdown]
# #Imputation
# Imputation is fairly intuitive. For the missing data in our dataset, we're going to replace it with values that come from similar records in our dataset that aren't null.
# To do this we're going to use the NearestNeighbors algorithm.

# %%
import pandas as pd
import numpy as np
import pylab as pl

# %%
df = pd.read_csv("./data/credit-data-post-import.csv")

# %% [markdown]
# ##Cross Validation
# We're going to use the simplest type of cross validation. we'll simply split our data into 2 groups: training and test. we'll use the training set to calibrate our model and then use the test set to  evaluate how effective it is.

# %%
is_test = np.random.uniform(0, 1, len(df)) > 0.75
train = df[is_test==False]
test = df[is_test==True]

# %%
len(train), len(test)
# Out:
# (112797, 37203)

# %% [markdown]
# ##Be sure to calibrate the imputation with the training set

# %%
from sklearn.neighbors import KNeighborsRegressor

income_imputer = KNeighborsRegressor(n_neighbors=1)

#split our data into 2 groups; data containing nulls and data 
# not containing nulls we'll train on the latter and make
# 'predictions' on the null data to impute monthly_income
train_w_monthly_income = train[train.monthly_income.isnull()==False]
train_w_null_monthly_income = train[train.monthly_income.isnull()==True]

# %%
train_w_monthly_income.corr()
# Out:
#                                              serious_dlqin2yrs  \
# serious_dlqin2yrs                                     1.000000
# revolving_utilization_of_unsecured_lines             -0.002199
# age                                                  -0.102317
# number_of_time30-59_days_past_due_not_worse           0.119989
# debt_ratio                                           -0.003401
# monthly_income                                       -0.025072
# number_of_open_credit_lines_and_loans                -0.027214
# number_of_times90_days_late                           0.107813
# number_real_estate_loans_or_lines                    -0.001820
# number_of_time60-89_days_past_due_not_worse           0.089610
# number_of_dependents                                  0.043886
#
#                                              revolving_utilization_of_unsecured_lines  \
# serious_dlqin2yrs                                                           -0.002199
# revolving_utilization_of_unsecured_lines                                     1.000000
# age                                                                         -0.006302
# number_of_time30-59_days_past_due_not_worse                                 -0.000945
# debt_ratio                                                                  -0.001223
# monthly_income                                                               0.009773
# number_of_open_credit_lines_and_loans                                       -0.009248
# number_of_times90_days_late                                                 -0.001050
# number_real_estate_loans_or_lines                                            0.006509
# number_of_time60-89_days_past_due_not_worse                                 -0.000872
# number_of_dependents                                                         0.002626
#
#                                                   age  \
# serious_dlqin2yrs                           -0.102317
# revolving_utilization_of_unsecured_lines    -0.006302
# age                                          1.000000
# number_of_time30-59_days_past_due_not_worse -0.047870
# debt_ratio                                  -0.000990
# monthly_income                               0.043596
# number_of_open_credit_lines_and_loans        0.186183
# number_of_times90_days_late                 -0.046621
# number_real_estate_loans_or_lines            0.065057
# number_of_time60-89_days_past_due_not_worse -0.042452
# number_of_dependents                        -0.206410
#
#                                              number_of_time30-59_days_past_due_not_worse  \
# serious_dlqin2yrs                                                               0.119989
# revolving_utilization_of_unsecured_lines                                       -0.000945
# age                                                                            -0.047870
# number_of_time30-59_days_past_due_not_worse                                     1.000000
# debt_ratio                                                                     -0.001979
# monthly_income                                                                 -0.012287
# number_of_open_credit_lines_and_loans                                          -0.042499
# number_of_times90_days_late                                                     0.974234
# number_real_estate_loans_or_lines                                              -0.023889
# number_of_time60-89_days_past_due_not_worse                                     0.979387
# number_of_dependents                                                            0.001705
#
#                                              debt_ratio  monthly_income  \
# serious_dlqin2yrs                             -0.003401       -0.025072
# revolving_utilization_of_unsecured_lines      -0.001223        0.009773
# age                                           -0.000990        0.043596
# number_of_time30-59_days_past_due_not_worse   -0.001979       -0.012287
# debt_ratio                                     1.000000       -0.032702
# monthly_income                                -0.032702        1.000000
# number_of_open_credit_lines_and_loans          0.007284        0.106197
# number_of_times90_days_late                   -0.002497       -0.015135
# number_real_estate_loans_or_lines              0.017110        0.147581
# number_of_time60-89_days_past_due_not_worse   -0.001817       -0.013156
# number_of_dependents                           0.009838        0.072476
#
#                                              number_of_open_credit_lines_and_loans  \
# serious_dlqin2yrs                                                        -0.027214
# revolving_utilization_of_unsecured_lines                                 -0.009248
# age                                                                       0.186183
# number_of_time30-59_days_past_due_not_worse                              -0.042499
# debt_ratio                                                                0.007284
# monthly_income                                                            0.106197
# number_of_open_credit_lines_and_loans                                     1.000000
# number_of_times90_days_late                                              -0.071603
# number_real_estate_loans_or_lines                                         0.426846
# number_of_time60-89_days_past_due_not_worse                              -0.060784
# number_of_dependents                                                      0.036491
#
#                                              number_of_times90_days_late  \
# serious_dlqin2yrs                                               0.107813
# revolving_utilization_of_unsecured_lines                       -0.001050
# age                                                            -0.046621
# number_of_time30-59_days_past_due_not_worse                     0.974234
# debt_ratio                                                     -0.002497
# monthly_income                                                 -0.015135
# number_of_open_credit_lines_and_loans                          -0.071603
# number_of_times90_days_late                                     1.000000
# number_real_estate_loans_or_lines                              -0.040229
# number_of_time60-89_days_past_due_not_worse                     0.988706
# number_of_dependents                                           -0.005733
#
#                                              number_real_estate_loans_or_lines  \
# serious_dlqin2yrs                                                    -0.001820
# revolving_utilization_of_unsecured_lines                              0.006509
# age                                                                   0.065057
# number_of_time30-59_days_past_due_not_worse                          -0.023889
# debt_ratio                                                            0.017110
# monthly_income                                                        0.147581
# number_of_open_credit_lines_and_loans                                 0.426846
# number_of_times90_days_late                                          -0.040229
# number_real_estate_loans_or_lines                                     1.000000
# number_of_time60-89_days_past_due_not_worse                          -0.033967
# number_of_dependents                                                  0.118667
#
#                                              number_of_time60-89_days_past_due_not_worse  \
# serious_dlqin2yrs                                                               0.089610
# revolving_utilization_of_unsecured_lines                                       -0.000872
# age                                                                            -0.042452
# number_of_time30-59_days_past_due_not_worse                                     0.979387
# debt_ratio                                                                     -0.001817
# monthly_income                                                                 -0.013156
# number_of_open_credit_lines_and_loans                                          -0.060784
# number_of_times90_days_late                                                     0.988706
# number_real_estate_loans_or_lines                                              -0.033967
# number_of_time60-89_days_past_due_not_worse                                     1.000000
# number_of_dependents                                                           -0.006917
#
#                                              number_of_dependents
# serious_dlqin2yrs                                        0.043886
# revolving_utilization_of_unsecured_lines                 0.002626
# age                                                     -0.206410
# number_of_time30-59_days_past_due_not_worse              0.001705
# debt_ratio                                               0.009838
# monthly_income                                           0.072476
# number_of_open_credit_lines_and_loans                    0.036491
# number_of_times90_days_late                             -0.005733
# number_real_estate_loans_or_lines                        0.118667
# number_of_time60-89_days_past_due_not_worse             -0.006917
# number_of_dependents                                     1.000000
#
# [11 rows x 11 columns]

# %%
train_w_monthly_income.corr().ix[:,5]
# Out:
# serious_dlqin2yrs                             -0.025072
# revolving_utilization_of_unsecured_lines       0.009773
# age                                            0.043596
# number_of_time30-59_days_past_due_not_worse   -0.012287
# debt_ratio                                    -0.032702
# monthly_income                                 1.000000
# number_of_open_credit_lines_and_loans          0.106197
# number_of_times90_days_late                   -0.015135
# number_real_estate_loans_or_lines              0.147581
# number_of_time60-89_days_past_due_not_worse   -0.013156
# number_of_dependents                           0.072476
# Name: monthly_income, dtype: float64

# %%
cols = ['number_real_estate_loans_or_lines', 'number_of_open_credit_lines_and_loans']
income_imputer.fit(train_w_monthly_income[cols], train_w_monthly_income.monthly_income)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           n_neighbors=1, p=2, weights='uniform')

# %% [markdown]
# ##Replace the mising values

# %%
new_values = income_imputer.predict(train_w_null_monthly_income[cols])

# %%
train_w_null_monthly_income['monthly_income'] = new_values
new_values
# Out:
# -c:1: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead
# array([ 17166.,   6424.,   9919., ...,   4383.,   4200.,   6500.])

# %%
#combine the data back together
train = train_w_monthly_income.append(train_w_null_monthly_income)
len(train)
# Out:
# 112797

# %%
test['monthly_income_imputed'] = income_imputer.predict(test[cols])
test.head()
# Out:
#     serious_dlqin2yrs  revolving_utilization_of_unsecured_lines  age  \
# 0                   1                                  0.766127   45
# 9                   0                                  0.189169   57
# 15                  0                                  0.548458   64
# 17                  0                                  0.166284   53
# 18                  0                                  0.221813   43
#
#     number_of_time30-59_days_past_due_not_worse  debt_ratio  monthly_income  \
# 0                                             2    0.802982            9120
# 9                                             0    0.606291           23684
# 15                                            0    0.209892           11362
# 17                                            0    0.188274            8800
# 18                                            0    0.527888            3280
#
#     number_of_open_credit_lines_and_loans  number_of_times90_days_late  \
# 0                                      13                            0
# 9                                       9                            0
# 15                                      7                            0
# 17                                      7                            0
# 18                                      7                            0
#
#     number_real_estate_loans_or_lines  \
# 0                                   6
# 9                                   4
# 15                                  1
# 17                                  0
# 18                                  1
#
#     number_of_time60-89_days_past_due_not_worse  number_of_dependents  \
# 0                                             0                     2
# 9                                             0                     2
# 15                                            0                     2
# 17                                            0                     0
# 18                                            0                     2
#
#     monthly_income_imputed
# 0                    14500
# 9                    11800
# 15                    5300
# 17                    9000
# 18                    5300
#
# [5 rows x 12 columns]

# %%
test['monthly_income'] = np.where(test.monthly_income.isnull(), test.monthly_income_imputed,
                                  test.monthly_income)
# Out:
# -c:2: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead

# %%
print pd.value_counts(train.monthly_income.isnull())
print pd.value_counts(test.monthly_income.isnull())
# Out:
# False    112797
# dtype: int64
# False    37203
# dtype: int64

# %%
train.to_csv("./data/credit-data-trainingset.csv", index=False)
test.to_csv("./data/credit-data-testset.csv", index=False)

# %% [markdown]
# ##Trying your own imputation strategy
# Partner with the person next to you and think of other ways you might be able to impute missing valus for the `monthly_income` column.
#
# Things to consider:
#
# - Are `number_of_open_credit_lines_and_loans` and `number_real_estate_loans_or_lines` the best predictors?
# - What are some other methods you could use for replacing nulls?
# - What about handling outlying values? Should a montly income of $3MM be treated as missing?
# - Check out the [scikit-learn docs](http://scikit-learn.org/stable/auto_examples/imputation.html) for more examples
# - How might you evaluate the effectiveness of your imputation?

# %% [markdown]
# ##We just did the following
#
# - Split our data into a training set for building our model and a test set for evaluating its performance
# - Used KNearestNeighbors to fill in missing values for `monthly_income`

# %%
# %hist
# Out:
# import pandas as pd
# import numpy as np
# import pylab as pl
# df = pd.read_csv("./data/credit-data-post-import.csv")
# is_test = np.random.uniform(0, 1, len(df)) > 0.75
# train = df[is_test==False]
# test = df[is_test==True]
# len(train), len(test)
# from sklearn.neighbors import KNeighborsRegressor
#
# income_imputer = KNeighborsRegressor(n_neighbors=1)
#
# #split our data into 2 groups; data containing nulls and data
# # not containing nulls we'll train on the latter and make
# # 'predictions' on the null data to impute monthly_income
# train_w_monthly_income = train[train.monthly_income.isnull()==False]
# train_w_null_monthly_income = train[train.monthly_income.isnull()==True]
# train_w_monthly_income.corr()
# train_w_monthly_income.corr().ix[:,5]
# cols = ['number_real_estate_loans_or_lines', 'number_of_open_credit_lines_and_loans']
# income_imputer.fit(train_w_monthly_income[cols], train_w_monthly_income.monthly_income)
# new_values = income_imputer.predict(train_w_null_monthly_income[cols])
# train_w_null_monthly_income['monthly_income'] = new_values
# new_values
# #combine the data back together
# train = train_w_monthly_income.append(train_w_null_monthly_income)
# len(train)
# test['monthly_income_imputed'] = income_imputer.predict(test[cols])
# test.head()
# test['monthly_income'] = np.where(test.monthly_income.isnull(), test.monthly_income_imputed,
#                                   test.monthly_income)
# print pd.value_counts(train.monthly_income.isnull())
# print pd.value_counts(test.monthly_income.isnull())
# train.to_csv("./data/credit-data-trainingset.csv", index=False)
# test.to_csv("./data/credit-data-testset.csv", index=False)
# %hist
